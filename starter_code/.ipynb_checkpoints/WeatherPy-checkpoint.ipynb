# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests 
import scipy.stats as st
import time
from scipy.stats import linregress

import datetime
d = datetime.datetime.today()
date = f'{d.month}-{d.day}-{d.year}'

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_range
# Out:
# (-90, 90)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# # Save config information.
# url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key + 'q='
# "

# for city in cities:
#         query_url =url+city
#         request.get(query_url)
        
# # Build partial query URL
# # query_url = f"{url}appid={weather_api_key}&units={units}&q="

# response=request.get(query_url).json()

# %%
# Show the json for an example city (Chicago) so we can know how to traverse it for our list of cities
test = requests.get(f'{query_url}miami').json()
display(test)
# Out:
# {'coord': {'lon': -80.1937, 'lat': 25.7743},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 75.85,
#   'feels_like': 76.64,
#   'temp_min': 73.99,
#   'temp_max': 78.01,
#   'pressure': 1020,
#   'humidity': 73},
#  'visibility': 10000,
#  'wind': {'speed': 9.22, 'deg': 110},
#  'clouds': {'all': 1},
#  'dt': 1612914137,
#  'sys': {'type': 1,
#   'id': 5222,
#   'country': 'US',
#   'sunrise': 1612871999,
#   'sunset': 1612912208},
#  'timezone': -18000,
#  'id': 4164138,
#  'name': 'Miami',
#  'cod': 200}

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

city_list = []

counter = 0

print('Beginning Data Retrieval')
print('-----------------------------')
# Loop through the list of cities and perform a request for data on each
for city in cities:
    
    response_json = requests.get(query_url + city).json()
    
    try:
        
        cloudiness.append(response_json['clouds']['all'])
        country.append(response_json['sys']['country'])
        date.append(response_json['dt'])
        humidity.append(response_json['main']['humidity'])
        lat.append(response_json['coord']['lat'])
        lng.append(response_json['coord']['lon'])
        max_temp.append(response_json['main']['temp_max'])
        wind_speed.append(response_json['wind']['speed'])
        
        city_list.append(city)
        
        counter += 1
        print(f"Processing Record {counter} | {city}")

    except:
        # Append null values
        print("City not found. Skipping...")
        pass

print('-----------------------------')
print('Data Retrieval Complete')    
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | vaini
# Processing Record 2 | winnemucca
# Processing Record 3 | port lincoln
# Processing Record 4 | butaritari
# Processing Record 5 | olinda
# Processing Record 6 | vega de alatorre
# Processing Record 7 | starkville
# City not found. Skipping...
# Processing Record 8 | ushuaia
# Processing Record 9 | swift current
# Processing Record 10 | alofi
# Processing Record 11 | arandis
# Processing Record 12 | klaksvik
# Processing Record 13 | portland
# City not found. Skipping...
# Processing Record 14 | tura
# Processing Record 15 | gizo
# Processing Record 16 | nishihara
# Processing Record 17 | hobart
# Processing Record 18 | pevek
# Processing Record 19 | cayenne
# Processing Record 20 | jamestown
# Processing Record 21 | atuona
# Processing Record 22 | touros
# Processing Record 23 | jinchang
# Processing Record 24 | egvekinot
# Processing Record 25 | beaufort
# Processing Record 26 | muros
# Processing Record 27 | mar del plata
# Processing Record 28 | port alfred
# Processing Record 29 | avarua
# Processing Record 30 | adrar
# Processing Record 31 | kapaa
# City not found. Skipping...
# Processing Record 32 | verkhoyansk
# Processing Record 33 | trebisacce
# Processing Record 34 | severo-kurilsk
# Processing Record 35 | chifeng
# Processing Record 36 | albany
# Processing Record 37 | busselton
# City not found. Skipping...
# Processing Record 38 | kingman
# Processing Record 39 | kavaratti
# Processing Record 40 | san quintin
# Processing Record 41 | rikitea
# Processing Record 42 | hirara
# Processing Record 43 | narsaq
# Processing Record 44 | santa luzia
# Processing Record 45 | trincomalee
# Processing Record 46 | bluff
# Processing Record 47 | ola
# Processing Record 48 | mataura
# Processing Record 49 | kahului
# Processing Record 50 | port elizabeth
# Processing Record 51 | vestmannaeyjar
# Processing Record 52 | ialibu
# City not found. Skipping...
# Processing Record 53 | kaitangata
# Processing Record 54 | yagodnoye
# Processing Record 55 | nanortalik
# Processing Record 56 | qaanaaq
# Processing Record 57 | nampula
# Processing Record 58 | eenhana
# Processing Record 59 | lebu
# Processing Record 60 | aklavik
# Processing Record 61 | ponta do sol
# Processing Record 62 | praia da vitoria
# Processing Record 63 | yellowknife
# Processing Record 64 | airai
# Processing Record 65 | weligama
# Processing Record 66 | ribeira brava
# Processing Record 67 | tuktoyaktuk
# Processing Record 68 | bredasdorp
# Processing Record 69 | jalu
# Processing Record 70 | fort-shevchenko
# Processing Record 71 | coquimbo
# Processing Record 72 | cape town
# Processing Record 73 | namibe
# Processing Record 74 | tungor
# Processing Record 75 | san patricio
# Processing Record 76 | kununurra
# Processing Record 77 | east london
# Processing Record 78 | atasu
# Processing Record 79 | chanika
# Processing Record 80 | moyo
# Processing Record 81 | teguldet
# City not found. Skipping...
# Processing Record 82 | novyy urengoy
# City not found. Skipping...
# Processing Record 83 | georgetown
# Processing Record 84 | qui nhon
# Processing Record 85 | sechura
# Processing Record 86 | mercedes
# Processing Record 87 | finote selam
# Processing Record 88 | willowmore
# Processing Record 89 | mogwase
# Processing Record 90 | neiafu
# Processing Record 91 | te anau
# Processing Record 92 | aneho
# Processing Record 93 | hilo
# Processing Record 94 | los llanos de aridane
# Processing Record 95 | la rioja
# Processing Record 96 | kyzyl-mazhalyk
# Processing Record 97 | barrow
# Processing Record 98 | wagar
# Processing Record 99 | new norfolk
# Processing Record 100 | beringovskiy
# Processing Record 101 | castro
# Processing Record 102 | zeya
# Processing Record 103 | kodiak
# Processing Record 104 | nikolskoye
# Processing Record 105 | cantapoy
# Processing Record 106 | madimba
# Processing Record 107 | sorland
# Processing Record 108 | san policarpo
# Processing Record 109 | richards bay
# Processing Record 110 | tiksi
# Processing Record 111 | hervey bay
# Processing Record 112 | shelburne
# Processing Record 113 | lorengau
# Processing Record 114 | santa maria
# Processing Record 115 | punta arenas
# Processing Record 116 | naze
# Processing Record 117 | merrill
# Processing Record 118 | ancud
# Processing Record 119 | hyeres
# Processing Record 120 | whitehorse
# Processing Record 121 | gat
# Processing Record 122 | trairi
# Processing Record 123 | ciudad bolivar
# Processing Record 124 | nabire
# Processing Record 125 | saint-francois
# Processing Record 126 | saint helens
# Processing Record 127 | kavieng
# Processing Record 128 | sao joao da barra
# Processing Record 129 | chuy
# Processing Record 130 | luanda
# Processing Record 131 | port augusta
# Processing Record 132 | dengzhou
# Processing Record 133 | mareeba
# Processing Record 134 | khatanga
# Processing Record 135 | kruisfontein
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 136 | srednekolymsk
# Processing Record 137 | trofors
# Processing Record 138 | puerto ayora
# Processing Record 139 | fukue
# Processing Record 140 | jiwani
# Processing Record 141 | nantucket
# Processing Record 142 | wuwei
# Processing Record 143 | mehriz
# Processing Record 144 | mwaya
# Processing Record 145 | hithadhoo
# Processing Record 146 | sao joaquim
# Processing Record 147 | tabas
# Processing Record 148 | karratha
# City not found. Skipping...
# Processing Record 149 | thompson
# Processing Record 150 | puerto el triunfo
# Processing Record 151 | ceyhan
# Processing Record 152 | yulara
# Processing Record 153 | namuac
# Processing Record 154 | namatanai
# Processing Record 155 | kargalinskaya
# Processing Record 156 | atar
# Processing Record 157 | husavik
# Processing Record 158 | hailar
# City not found. Skipping...
# Processing Record 159 | ahuimanu
# Processing Record 160 | kaseda
# Processing Record 161 | cidreira
# Processing Record 162 | provideniya
# City not found. Skipping...
# Processing Record 163 | torbay
# City not found. Skipping...
# Processing Record 164 | hobyo
# Processing Record 165 | constitucion
# Processing Record 166 | ucluelet
# Processing Record 167 | mattru
# Processing Record 168 | drezdenko
# Processing Record 169 | lata
# Processing Record 170 | umm lajj
# Processing Record 171 | tougue
# City not found. Skipping...
# Processing Record 172 | khandyga
# Processing Record 173 | upernavik
# Processing Record 174 | plettenberg bay
# Processing Record 175 | urubicha
# Processing Record 176 | bati
# Processing Record 177 | saldanha
# Processing Record 178 | osuna
# Processing Record 179 | bubaque
# Processing Record 180 | muisne
# Processing Record 181 | padang
# Processing Record 182 | ribeira grande
# Processing Record 183 | cabo san lucas
# Processing Record 184 | bethel
# Processing Record 185 | shingu
# Processing Record 186 | belaya gora
# Processing Record 187 | korla
# Processing Record 188 | fasa
# Processing Record 189 | bull savanna
# Processing Record 190 | dikson
# Processing Record 191 | boma
# Processing Record 192 | fortuna
# Processing Record 193 | evensk
# Processing Record 194 | goderich
# Processing Record 195 | hambantota
# Processing Record 196 | nacala
# Processing Record 197 | sitka
# Processing Record 198 | natal
# Processing Record 199 | derzhavinsk
# City not found. Skipping...
# Processing Record 200 | dingzhou
# Processing Record 201 | port hardy
# Processing Record 202 | andenes
# Processing Record 203 | torit
# Processing Record 204 | la asuncion
# Processing Record 205 | hamilton
# Processing Record 206 | lincoln
# Processing Record 207 | bengkulu
# Processing Record 208 | waddan
# Processing Record 209 | chokurdakh
# Processing Record 210 | katsuura
# Processing Record 211 | yumen
# Processing Record 212 | belyy
# Processing Record 213 | nome
# Processing Record 214 | port blair
# Processing Record 215 | necochea
# Processing Record 216 | shubarkuduk
# Processing Record 217 | merauke
# Processing Record 218 | ust-barguzin
# City not found. Skipping...
# Processing Record 219 | sancti spiritus
# Processing Record 220 | saint george
# Processing Record 221 | dhidhdhoo
# Processing Record 222 | faanui
# Processing Record 223 | aksu
# Processing Record 224 | chernyshevskiy
# Processing Record 225 | vardo
# Processing Record 226 | acarau
# Processing Record 227 | salalah
# Processing Record 228 | sarangani
# Processing Record 229 | general roca
# Processing Record 230 | walvis bay
# Processing Record 231 | mount isa
# Processing Record 232 | sirjan
# Processing Record 233 | mehamn
# Processing Record 234 | geraldton
# Processing Record 235 | iqaluit
# Processing Record 236 | kamenka
# Processing Record 237 | saskylakh
# Processing Record 238 | tazovskiy
# Processing Record 239 | cordoba
# Processing Record 240 | dingle
# Processing Record 241 | la union
# Processing Record 242 | lukiv
# Processing Record 243 | bambous virieux
# Processing Record 244 | at-bashi
# Processing Record 245 | veinticinco de mayo
# Processing Record 246 | arraial do cabo
# Processing Record 247 | yangjiang
# Processing Record 248 | ostrovnoy
# Processing Record 249 | saint-georges
# Processing Record 250 | chumikan
# Processing Record 251 | baoqing
# Processing Record 252 | esperance
# Processing Record 253 | churapcha
# Processing Record 254 | piranshahr
# Processing Record 255 | keti bandar
# Processing Record 256 | longyearbyen
# Processing Record 257 | comodoro rivadavia
# City not found. Skipping...
# Processing Record 258 | charters towers
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 259 | margate
# Processing Record 260 | cottonwood heights
# Processing Record 261 | teguise
# Processing Record 262 | cap malheureux
# City not found. Skipping...
# Processing Record 263 | terracina
# Processing Record 264 | ginda
# City not found. Skipping...
# Processing Record 265 | dali
# Processing Record 266 | balkhash
# Processing Record 267 | puri
# Processing Record 268 | tasiilaq
# Processing Record 269 | moussoro
# Processing Record 270 | srivardhan
# Processing Record 271 | mabaruma
# Processing Record 272 | coihueco
# Processing Record 273 | hermanus
# Processing Record 274 | jacareacanga
# Processing Record 275 | nouadhibou
# Processing Record 276 | caravelas
# Processing Record 277 | pitea
# Processing Record 278 | rapid valley
# Processing Record 279 | orlik
# Processing Record 280 | lashio
# Processing Record 281 | mabini
# Processing Record 282 | sabla
# Processing Record 283 | palmas bellas
# City not found. Skipping...
# Processing Record 284 | port hedland
# Processing Record 285 | bilibino
# Processing Record 286 | ust-ishim
# City not found. Skipping...
# Processing Record 287 | luderitz
# Processing Record 288 | naraura
# Processing Record 289 | benguela
# Processing Record 290 | inyonga
# Processing Record 291 | grand gaube
# Processing Record 292 | bouca
# Processing Record 293 | kutum
# Processing Record 294 | tarrafal
# Processing Record 295 | laguna
# Processing Record 296 | ahipara
# Processing Record 297 | rio gallegos
# Processing Record 298 | sao filipe
# Processing Record 299 | chibombo
# Processing Record 300 | abu dhabi
# Processing Record 301 | palau
# Processing Record 302 | mahebourg
# Processing Record 303 | maniitsoq
# Processing Record 304 | cabra
# Processing Record 305 | dunedin
# Processing Record 306 | novikovo
# Processing Record 307 | littleton
# Processing Record 308 | wahiawa
# Processing Record 309 | ilam
# Processing Record 310 | asau
# Processing Record 311 | chimore
# Processing Record 312 | sola
# Processing Record 313 | luis correia
# Processing Record 314 | darnah
# Processing Record 315 | leningradskiy
# Processing Record 316 | tingi
# Processing Record 317 | kindu
# Processing Record 318 | baykit
# Processing Record 319 | vila franca do campo
# Processing Record 320 | oistins
# Processing Record 321 | thinadhoo
# Processing Record 322 | hami
# Processing Record 323 | chapais
# Processing Record 324 | velka bites
# Processing Record 325 | pasighat
# Processing Record 326 | victoria
# City not found. Skipping...
# Processing Record 327 | waipawa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 328 | shimoda
# Processing Record 329 | tateyama
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 330 | forst
# City not found. Skipping...
# Processing Record 331 | haikou
# Processing Record 332 | yeppoon
# Processing Record 333 | maple creek
# Processing Record 334 | skjervoy
# Processing Record 335 | jangaon
# Processing Record 336 | katobu
# Processing Record 337 | vila velha
# Processing Record 338 | porto walter
# Processing Record 339 | cururupu
# Processing Record 340 | iwanai
# Processing Record 341 | makokou
# Processing Record 342 | kuching
# Processing Record 343 | ilulissat
# Processing Record 344 | kudymkar
# Processing Record 345 | talcahuano
# Processing Record 346 | acari
# Processing Record 347 | mitsamiouli
# City not found. Skipping...
# Processing Record 348 | beboto
# Processing Record 349 | ocean city
# Processing Record 350 | ha giang
# Processing Record 351 | kungurtug
# Processing Record 352 | eureka
# City not found. Skipping...
# Processing Record 353 | sozimskiy
# Processing Record 354 | mount gambier
# Processing Record 355 | beian
# Processing Record 356 | naryan-mar
# Processing Record 357 | berlevag
# Processing Record 358 | isangel
# Processing Record 359 | loncoche
# Processing Record 360 | whitianga
# City not found. Skipping...
# Processing Record 361 | kargasok
# Processing Record 362 | qixia
# Processing Record 363 | savonlinna
# Processing Record 364 | bulgan
# Processing Record 365 | glendive
# Processing Record 366 | mehran
# Processing Record 367 | sabzevar
# Processing Record 368 | atbasar
# Processing Record 369 | bolobo
# Processing Record 370 | poum
# Processing Record 371 | imphal
# Processing Record 372 | bathsheba
# Processing Record 373 | tautira
# Processing Record 374 | juazeiro
# Processing Record 375 | sao jose da coroa grande
# Processing Record 376 | belomorsk
# Processing Record 377 | kuvandyk
# Processing Record 378 | amursk
# City not found. Skipping...
# Processing Record 379 | coihaique
# Processing Record 380 | machilipatnam
# Processing Record 381 | rancho palos verdes
# City not found. Skipping...
# Processing Record 382 | deputatskiy
# Processing Record 383 | arman
# Processing Record 384 | flinders
# Processing Record 385 | vao
# Processing Record 386 | kurilsk
# Processing Record 387 | marystown
# Processing Record 388 | carnarvon
# Processing Record 389 | avera
# Processing Record 390 | kirkenaer
# Processing Record 391 | mpika
# Processing Record 392 | itarema
# Processing Record 393 | filadelfia
# Processing Record 394 | kangaatsiaq
# Processing Record 395 | maceio
# Processing Record 396 | bhunya
# Processing Record 397 | okhotsk
# Processing Record 398 | zhurivka
# Processing Record 399 | sinnamary
# Processing Record 400 | klyuchi
# Processing Record 401 | ylojarvi
# Processing Record 402 | ust-koksa
# Processing Record 403 | tezu
# Processing Record 404 | zgierz
# City not found. Skipping...
# Processing Record 405 | strezhevoy
# Processing Record 406 | okha
# Processing Record 407 | ponta delgada
# Processing Record 408 | port macquarie
# Processing Record 409 | hurghada
# Processing Record 410 | kharitonovo
# Processing Record 411 | pacific grove
# Processing Record 412 | samarai
# Processing Record 413 | tuatapere
# Processing Record 414 | biltine
# Processing Record 415 | tondano
# Processing Record 416 | luba
# Processing Record 417 | bergen
# Processing Record 418 | camabatela
# Processing Record 419 | ipora
# Processing Record 420 | bria
# Processing Record 421 | cherskiy
# Processing Record 422 | estepa
# Processing Record 423 | tabou
# Processing Record 424 | westport
# Processing Record 425 | piacabucu
# Processing Record 426 | wawa
# Processing Record 427 | puerto madryn
# Processing Record 428 | gazojak
# Processing Record 429 | yar-sale
# Processing Record 430 | vanimo
# Processing Record 431 | araouane
# Processing Record 432 | omboue
# Processing Record 433 | erenhot
# Processing Record 434 | iberia
# Processing Record 435 | butembo
# Processing Record 436 | pizarro
# Processing Record 437 | clarksburg
# Processing Record 438 | capreol
# Processing Record 439 | bahile
# City not found. Skipping...
# Processing Record 440 | swan hill
# Processing Record 441 | oulainen
# City not found. Skipping...
# Processing Record 442 | sur
# Processing Record 443 | duku
# Processing Record 444 | yining
# Processing Record 445 | akodia
# Processing Record 446 | viedma
# Processing Record 447 | hlotse
# Processing Record 448 | rocha
# Processing Record 449 | caernarfon
# Processing Record 450 | kwakoa
# Processing Record 451 | taltal
# Processing Record 452 | kotma
# Processing Record 453 | pelotas
# Processing Record 454 | igrim
# Processing Record 455 | tsumeb
# Processing Record 456 | bambanglipuro
# Processing Record 457 | talnakh
# Processing Record 458 | kaman
# Processing Record 459 | ambanja
# Processing Record 460 | houma
# Processing Record 461 | camacha
# Processing Record 462 | halmstad
# Processing Record 463 | santa cruz
# Processing Record 464 | nambutalai
# Processing Record 465 | hegang
# Processing Record 466 | presidencia roque saenz pena
# Processing Record 467 | aksarka
# Processing Record 468 | nynashamn
# Processing Record 469 | vaitape
# Processing Record 470 | oklahoma city
# Processing Record 471 | ussel
# Processing Record 472 | mao
# City not found. Skipping...
# Processing Record 473 | maarianhamina
# Processing Record 474 | dukat
# Processing Record 475 | mocuba
# Processing Record 476 | vanderhoof
# City not found. Skipping...
# Processing Record 477 | olafsvik
# Processing Record 478 | chegdomyn
# Processing Record 479 | henties bay
# Processing Record 480 | zhezkazgan
# Processing Record 481 | mungo
# Processing Record 482 | itoman
# Processing Record 483 | havre-saint-pierre
# Processing Record 484 | la palma
# Processing Record 485 | ayagoz
# Processing Record 486 | wencheng
# Processing Record 487 | aykhal
# Processing Record 488 | matias olimpio
# Processing Record 489 | guerrero negro
# Processing Record 490 | tazmalt
# Processing Record 491 | verkh-usugli
# Processing Record 492 | oktyabrskiy
# Processing Record 493 | makakilo city
# Processing Record 494 | castro verde
# Processing Record 495 | garmsar
# Processing Record 496 | kampli
# Processing Record 497 | pires do rio
# Processing Record 498 | san luis
# Processing Record 499 | tafo
# Processing Record 500 | hendek
# Processing Record 501 | ajaccio
# Processing Record 502 | huarmey
# Processing Record 503 | souillac
# Processing Record 504 | brest
# Processing Record 505 | graaff-reinet
# Processing Record 506 | shenzhen
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 507 | seymour
# Processing Record 508 | tomatlan
# Processing Record 509 | mazamari
# Processing Record 510 | kirakira
# Processing Record 511 | kushiro
# Processing Record 512 | appleton
# Processing Record 513 | half moon bay
# Processing Record 514 | patti
# Processing Record 515 | tala
# Processing Record 516 | cabedelo
# Processing Record 517 | tacuarembo
# Processing Record 518 | dzilam gonzalez
# Processing Record 519 | zhuhai
# Processing Record 520 | santa rosa
# Processing Record 521 | sainte-anne-des-monts
# Processing Record 522 | barra dos coqueiros
# Processing Record 523 | auki
# Processing Record 524 | karasjok
# Processing Record 525 | pemba
# Processing Record 526 | natitingou
# City not found. Skipping...
# Processing Record 527 | havelock
# Processing Record 528 | campbell river
# Processing Record 529 | muriti
# Processing Record 530 | bafoulabe
# Processing Record 531 | barra patuca
# Processing Record 532 | sumbe
# Processing Record 533 | iquique
# Processing Record 534 | gerash
# Processing Record 535 | stornoway
# Processing Record 536 | horuphav
# Processing Record 537 | grants
# Processing Record 538 | bridlington
# Processing Record 539 | homer
# Processing Record 540 | labe
# Processing Record 541 | launceston
# Processing Record 542 | hofn
# Processing Record 543 | dawlatabad
# Processing Record 544 | hualmay
# Processing Record 545 | luang prabang
# Processing Record 546 | sao felix do xingu
# Processing Record 547 | barcelona
# Processing Record 548 | honningsvag
# Processing Record 549 | beya
# Processing Record 550 | front royal
# Processing Record 551 | belmonte
# Processing Record 552 | porto novo
# Processing Record 553 | batagay-alyta
# Processing Record 554 | sisimiut
# Processing Record 555 | cochrane
# Processing Record 556 | sadovoye
# Processing Record 557 | krasnyy chikoy
# Processing Record 558 | arona
# Processing Record 559 | pisco
# City not found. Skipping...
# Processing Record 560 | ammon
# City not found. Skipping...
# Processing Record 561 | elizabeth city
# Processing Record 562 | zhangye
# Processing Record 563 | anadyr
# Processing Record 564 | ust-kut
# Processing Record 565 | odweyne
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
#
#
#
#
# * Display the DataFrame

# %%
city_df = pd.DataFrame({
    'City': city_list,
    'Cloudiness': cloudiness,
    'Country': country,
    'Date': date,
    'Humidity': humidity,
    'Lat': lat,
    'Lng': lng,
    'Max Temp': max_temp,
    'Wind Speed': wind_speed
})

display(city_df)

# Export Dataframe into a .csv
# city_df.to_csv(output_data_file)
# Out:
#                City  Cloudiness Country      Date  Humidity      Lat  \
# 0             vaini          90      TO  2-9-2021       100 -21.2000
# 1        winnemucca          90      US  2-9-2021        35  40.9730
# 2      port lincoln          14      AU  2-9-2021        46 -34.7333
# 3        butaritari          79      KI  2-9-2021        81   3.0707
# 4            olinda          20      BR  2-9-2021        69  -8.0089
# ..              ...         ...     ...       ...       ...      ...
# 560  elizabeth city          20      US  2-9-2021        76  36.2946
# 561         zhangye          43      CN  2-9-2021        74  38.9342
# 562          anadyr          38      RU  2-9-2021        56  64.7500
# 563         ust-kut          99      RU  2-9-2021        89  56.7938
# 564         odweyne          93      SO  2-9-2021        42   9.4092
#
#           Lng  Max Temp  Wind Speed
# 0   -175.2000     77.00       21.85
# 1   -117.7357     51.80        6.91
# 2    135.8667     76.75        9.33
# 3    172.7902     81.59       14.03
# 4    -34.8553     78.80        9.22
# ..        ...       ...         ...
# 560  -76.2511     55.40        5.84
# 561  100.4517     30.63        4.65
# 562  177.4833      5.00       13.42
# 563  105.7672      5.13        5.77
# 564   45.0640     64.72       23.67
#
# [565 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_df.loc[city_df['Humidity']>100]
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temp, Wind Speed]
# Index: []

# %%
city_df.loc[city_df['Cloudiness']<=100]
# Out:
#                City  Cloudiness Country      Date  Humidity      Lat  \
# 0             vaini          90      TO  2-9-2021       100 -21.2000
# 1        winnemucca          90      US  2-9-2021        35  40.9730
# 2      port lincoln          14      AU  2-9-2021        46 -34.7333
# 3        butaritari          79      KI  2-9-2021        81   3.0707
# 4            olinda          20      BR  2-9-2021        69  -8.0089
# ..              ...         ...     ...       ...       ...      ...
# 560  elizabeth city          20      US  2-9-2021        76  36.2946
# 561         zhangye          43      CN  2-9-2021        74  38.9342
# 562          anadyr          38      RU  2-9-2021        56  64.7500
# 563         ust-kut          99      RU  2-9-2021        89  56.7938
# 564         odweyne          93      SO  2-9-2021        42   9.4092
#
#           Lng  Max Temp  Wind Speed
# 0   -175.2000     77.00       21.85
# 1   -117.7357     51.80        6.91
# 2    135.8667     76.75        9.33
# 3    172.7902     81.59       14.03
# 4    -34.8553     78.80        9.22
# ..        ...       ...         ...
# 560  -76.2511     55.40        5.84
# 561  100.4517     30.63        4.65
# 562  177.4833      5.00       13.42
# 563  105.7672      5.13        5.77
# 564   45.0640     64.72       23.67
#
# [565 rows x 9 columns]

# %%
#  Get the indices of cities that have humidity over 100%.
indicies_to_drop=city_df.loc[city_df['Humidity']>100].index

cleancitydata=city_df.drop(indicies_to_drop)

# %%
cleancitydata
# Out:
#              City  Cloudiness Country      Date  Humidity      Lat       Lng  \
# 0      chokurdakh          98      RU  2-5-2021        86  70.6333  147.9167
# 1        qobustan          40      AZ  2-5-2021        93  40.0824   49.4120
# 2      bredasdorp           4      ZA  2-5-2021        82 -34.5322   20.0403
# 3    punta arenas           0      CL  2-5-2021        57 -53.1500  -70.9167
# 4          albany          20      US  2-5-2021        59  42.6001  -73.9662
# ..            ...         ...     ...       ...       ...      ...       ...
# 570           lar           0      IN  2-5-2021        78  26.2039   83.9717
# 571           vao           0      NC  2-5-2021        87 -22.6667  167.4833
# 572  san fernando          90      PH  2-5-2021        69  15.0286  120.6898
# 573           sur           0      OM  2-5-2021        70  22.5667   59.5289
# 574   fort nelson          75      CA  2-5-2021        64  58.8053 -122.7002
#
#      Max Temp  Wind Speed
# 0      -13.81       20.04
# 1       46.40       18.41
# 2       66.20        3.44
# 3       50.00       25.32
# 4       33.80        3.15
# ..        ...         ...
# 570     53.37        2.51
# 571     78.73       19.44
# 572     77.00       11.50
# 573     65.08        4.72
# 574    -13.00        4.61
#
# [575 rows x 9 columns]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

new_city_df = pd.DataFrame({
    'City': city_list,
    'Cloudiness': cloudiness,
    'Country': country,
    'Date': date,
    'Humidity': humidity,
    'Lat': lat,
    'Lng': lng,
    'Max Temp': max_temp,
    'Wind Speed': wind_speed
})

display(new_city_df)
# Out:
#              City  Cloudiness Country        Date  Humidity      Lat  \
# 0    ponta do sol          24      PT  1612817907        69  32.6667
# 1        hermanus           7      ZA  1612818096        86 -34.4187
# 2         rikitea          29      PF  1612818026        70 -23.1203
# 3       busselton          86      AU  1612818097        98 -33.6500
# 4          avarua          21      CK  1612818034        79 -21.2078
# ..            ...         ...     ...         ...       ...      ...
# 566  kudahuvadhoo          75      MV  1612818507        81   2.6708
# 567         dawei         100      MM  1612818145        81  14.0833
# 568        bereda         100      ES  1612818681        97  43.2686
# 569        shetpe         100      KZ  1612818141        83  44.1667
# 570   olovyannaya          23      RU  1612818683        92  50.9500
#
#           Lng  Max Temp  Wind Speed
# 0    -17.1000     57.99        3.00
# 1     19.2345     68.00        5.10
# 2   -134.9692     77.49        5.55
# 3    115.3333     57.00        9.17
# 4   -159.7750     84.20        6.91
# ..        ...       ...         ...
# 566   72.8944     81.45       18.41
# 567   98.2000     70.95        2.10
# 568   -7.5406     46.00        8.01
# 569   52.1167     27.30        9.40
# 570  115.5667      1.58        0.09
#
# [571 rows x 9 columns]

# %%
# plt.show("")

# %%
# x_values ['latitude']
# y_values ['max temps']
# plt.scatter(x_values,y_values)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Max Temp'

x = city_df['Lat']
y = city_df['Max Temp']

# Set color to the value of 'Max Temp' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='Greens', edgecolor='gray')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Max Temperature ({date})')
plt.grid()

# Save plot as png file in output folder
plt.savefig('../output_data/Lat_v_Temp.png')

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Humidity'

x = city_df['Lat']
y = city_df['Humidity']

# Set color to the value of 'Humidity' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='PuBuGn', edgecolor='gray')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Humidity ({date})')
plt.grid()

# Save plot as png file in output folder
plt.savefig('../output_data/Lat_v_Humidity.png')

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Cloudiness'

x = city_df['Lat']
y = city_df['Cloudiness']

# Set color to the value of 'Cloudiness' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='GnBu', edgecolor='gray')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Cloudiness ({date})')
plt.grid()

# Save plot as png file in output folder
plt.savefig('../output_data/Lat_v_Cloudiness.png')

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Wind Speed'

x = city_df['Lat']
y = city_df['Wind Speed']

# Set color to the value of 'Wind Speed' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='YlGn', edgecolor='gray')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs. Wind Speed ({date})')
plt.grid()

# Save plot as png file in output folder
plt.savefig('../output_data/Lat_v_WindSpeed.png')

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
def regressplot(x, y):
    
    correlation = st.pearsonr(x,y)

    # Print the answer to above calculation, but squared
    print(f"""The r-squared value is {round((correlation[0]**2),2)}""")

    # Calculate linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Plot linear regression on top of scatter plot
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# %%
northern_hemi=city_df.loc[city_df['Lat'] >=0]
southern_hemi=city_df.loc[city_df['Lat'] < 0]
southern_hemi
# Out:
#                    City  Cloudiness Country      Date  Humidity      Lat  \
# 0                 vaini          90      TO  2-9-2021       100 -21.2000
# 2          port lincoln          14      AU  2-9-2021        46 -34.7333
# 4                olinda          20      BR  2-9-2021        69  -8.0089
# 7               ushuaia          40      AR  2-9-2021        68 -54.8000
# 9                 alofi          75      NU  2-9-2021        79 -19.0595
# ..                  ...         ...     ...       ...       ...      ...
# 540          launceston          90      AU  2-9-2021        54 -41.4500
# 543             hualmay          26      PE  2-9-2021        79 -11.0964
# 545  sao felix do xingu         100      BR  2-9-2021        96  -6.6447
# 550            belmonte          20      BR  2-9-2021        78 -15.8631
# 558               pisco           0      PE  2-9-2021        69 -13.7000
#
#           Lng  Max Temp  Wind Speed
# 0   -175.2000     77.00       21.85
# 2    135.8667     76.75        9.33
# 4    -34.8553     78.80        9.22
# 7    -68.3000     69.80        2.30
# 9   -169.9187     84.20        9.22
# ..        ...       ...         ...
# 540  147.1667     61.00        5.75
# 543  -77.6139     72.09        6.76
# 545  -51.9950     72.03        1.83
# 550  -38.8828     77.00        4.61
# 558  -76.2167     77.00       21.85
#
# [179 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#  north and south dataframes
line_eq = regressplot(x = northern_hemi['Lat'], y = northern_hemi['Max Temp'])

# Annotate linear regression
plt.annotate(line_eq,(10,-10),fontsize=15,color="green")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

plt.savefig('../output_data/North_Temp.png')

plt.show()
# Out:
# The r-squared value is 0.76

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = southern_hemi['Lat'], y = southern_hemi['Max Temp'])

# Annotate linear regression
plt.annotate(line_eq,(-30,52),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

plt.savefig('../output_data/South_Temp.png')

plt.show()
# Out:
# The r-squared value is 0.25

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = northern_hemi['Lat'], y = northern_hemi['Humidity'])

# Annotate linear regression
plt.annotate(line_eq,(45,10),fontsize=15,color="blue")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig('../output_data/North_Humidity.png')

plt.show()
# Out:
# The r-squared value is 0.11

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = southern_hemi['Lat'], y = southern_hemi['Humidity'])

# Annotate linear regression
plt.annotate(line_eq,(-25,40),fontsize=15,color="green")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig('../output_data/South_Humidity.png')

plt.show()
# Out:
# The r-squared value is 0.11

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = northern_hemi['Lat'], y = northern_hemi['Cloudiness'])

# Annotate linear regression
plt.annotate(line_eq,(45,60),fontsize=15,color="green")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig('../output_data/North_Cloudiness.png')

plt.show()
# Out:
# The r-squared value is 0.0

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
city

# The correlation between these values in both hemispheres is almost identical.
# Out:
# 'sungairaya'

# %%
# Regression Function and pass appropriate parameters
line_eq = regressplot(x = southern_hemi['Lat'], y = southern_hemi['Cloudiness'])

# Annotate linear regression
plt.annotate(line_eq,(-57,50
                     ),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig('../output_data/South_Cloudiness.png')

plt.show()
# Out:
# The r-squared value is 0.14

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Regression Function and pass appropriate parameters
line_eq = regressplot(x = northern_hemi['Lat'], y = northern_hemi['Wind Speed'])

# Annotate linear regression
plt.annotate(line_eq,(10,30),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig('../output_data/North_WindSpeed.png')

plt.show()
# Out:
# The r-squared value is 0.01

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = southern_hemi['Lat'], y = southern_hemi['Wind Speed'])

# Annotate linear regression
plt.annotate(line_eq,(-48,22),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig('../output_data/South_WindSpeed.png')

plt.show()
# Out:
# The r-squared value is 0.01
