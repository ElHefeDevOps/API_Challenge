# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests 
import scipy.stats as st
import time
from scipy.stats import linregress

import datetime
d = datetime.datetime.today()
date = f'{d.month}-{d.day}-{d.year}'

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_range
# Out:
# (-90, 90)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# # Save config information.
# url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key + 'q='
# "

# for city in cities:
#         query_url =url+city
#         request.get(query_url)
        
# # Build partial query URL
# # query_url = f"{url}appid={weather_api_key}&units={units}&q="

# response=request.get(query_url).json()

# %%
# Show the json for an example city (Chicago) so we can know how to traverse it for our list of cities
test = requests.get(f'{query_url}miami').json()
display(test)
# Out:
# {'coord': {'lon': -80.1937, 'lat': 25.7743},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 82.94,
#   'feels_like': 89.37,
#   'temp_min': 80.01,
#   'temp_max': 86.02,
#   'pressure': 1018,
#   'humidity': 74},
#  'visibility': 10000,
#  'wind': {'speed': 1.99, 'deg': 100, 'gust': 8.01},
#  'clouds': {'all': 90},
#  'dt': 1624634838,
#  'sys': {'type': 2,
#   'id': 2009435,
#   'country': 'US',
#   'sunrise': 1624617065,
#   'sunset': 1624666542},
#  'timezone': -14400,
#  'id': 4164138,
#  'name': 'Miami',
#  'cod': 200}

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

city_list = []

counter = 0

print('Beginning Data Retrieval')
print('-----------------------------')
# Loop through the list of cities and perform a request for data on each
for city in cities:
    
    response_json = requests.get(query_url + city).json()
    
    try:
        
        cloudiness.append(response_json['clouds']['all'])
        country.append(response_json['sys']['country'])
        date.append(response_json['dt'])
        humidity.append(response_json['main']['humidity'])
        lat.append(response_json['coord']['lat'])
        lng.append(response_json['coord']['lon'])
        max_temp.append(response_json['main']['temp_max'])
        wind_speed.append(response_json['wind']['speed'])
        
        city_list.append(city)
        
        counter += 1
        print(f"Processing Record {counter} | {city}")

    except:
        # Append null values
        print("City not found. Skipping...")
        pass

print('-----------------------------')
print('Data Retrieval Complete')    
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | ushuaia
# Processing Record 2 | avarua
# Processing Record 3 | barrow
# Processing Record 4 | georgetown
# Processing Record 5 | coos bay
# Processing Record 6 | mataura
# Processing Record 7 | sabang
# Processing Record 8 | rikitea
# Processing Record 9 | tiksi
# Processing Record 10 | busselton
# Processing Record 11 | tuktoyaktuk
# Processing Record 12 | ocampo
# Processing Record 13 | sao filipe
# Processing Record 14 | saskylakh
# Processing Record 15 | paamiut
# Processing Record 16 | broken hill
# Processing Record 17 | lorengau
# Processing Record 18 | altamirano
# Processing Record 19 | werda
# Processing Record 20 | boende
# Processing Record 21 | kaitangata
# Processing Record 22 | jamestown
# Processing Record 23 | albany
# City not found. Skipping...
# Processing Record 24 | port alfred
# Processing Record 25 | hermanus
# Processing Record 26 | hilo
# Processing Record 27 | cherskiy
# City not found. Skipping...
# Processing Record 28 | sao joao da barra
# City not found. Skipping...
# Processing Record 29 | new norfolk
# Processing Record 30 | newport
# Processing Record 31 | vaini
# Processing Record 32 | hobart
# City not found. Skipping...
# Processing Record 33 | guisijan
# Processing Record 34 | bambous virieux
# Processing Record 35 | tura
# Processing Record 36 | peto
# Processing Record 37 | fortuna
# Processing Record 38 | sioux lookout
# Processing Record 39 | lebu
# Processing Record 40 | khatanga
# Processing Record 41 | okha
# Processing Record 42 | port elizabeth
# Processing Record 43 | ribeira grande
# Processing Record 44 | airai
# Processing Record 45 | florida
# Processing Record 46 | santa vitoria do palmar
# Processing Record 47 | yasenskaya
# Processing Record 48 | chuy
# Processing Record 49 | kununurra
# Processing Record 50 | port-cartier
# Processing Record 51 | ajdabiya
# Processing Record 52 | mahebourg
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 53 | saldanha
# Processing Record 54 | lasa
# Processing Record 55 | ponta do sol
# Processing Record 56 | comodoro rivadavia
# Processing Record 57 | thompson
# Processing Record 58 | nabha
# Processing Record 59 | porbandar
# Processing Record 60 | chokurdakh
# Processing Record 61 | yenagoa
# Processing Record 62 | saint-philippe
# Processing Record 63 | burnie
# Processing Record 64 | sampit
# City not found. Skipping...
# Processing Record 65 | malakal
# Processing Record 66 | charlestown
# Processing Record 67 | belmonte
# Processing Record 68 | mishan
# Processing Record 69 | saint george
# Processing Record 70 | belaya gora
# Processing Record 71 | kapaa
# Processing Record 72 | qaanaaq
# Processing Record 73 | hirara
# City not found. Skipping...
# Processing Record 74 | ostrovnoy
# City not found. Skipping...
# Processing Record 75 | meulaboh
# City not found. Skipping...
# Processing Record 76 | nome
# Processing Record 77 | lazaro cardenas
# Processing Record 78 | kautokeino
# City not found. Skipping...
# Processing Record 79 | ancud
# Processing Record 80 | olafsvik
# Processing Record 81 | puerto ayora
# City not found. Skipping...
# Processing Record 82 | boden
# Processing Record 83 | castro
# City not found. Skipping...
# Processing Record 84 | ixtapa
# Processing Record 85 | punta arenas
# City not found. Skipping...
# Processing Record 86 | vanimo
# Processing Record 87 | mayo
# Processing Record 88 | tilichiki
# Processing Record 89 | baruun-urt
# City not found. Skipping...
# Processing Record 90 | butaritari
# Processing Record 91 | bethel
# Processing Record 92 | clyde river
# Processing Record 93 | komsomolskiy
# Processing Record 94 | yellowknife
# Processing Record 95 | cape town
# Processing Record 96 | lebedinyy
# Processing Record 97 | great yarmouth
# Processing Record 98 | nemuro
# Processing Record 99 | touros
# Processing Record 100 | pangody
# Processing Record 101 | tiarei
# Processing Record 102 | miles city
# Processing Record 103 | hasanabad
# Processing Record 104 | luderitz
# Processing Record 105 | rawson
# Processing Record 106 | ryotsu
# Processing Record 107 | murgab
# Processing Record 108 | berbera
# Processing Record 109 | puerto carreno
# Processing Record 110 | kavieng
# Processing Record 111 | krasnoselkup
# Processing Record 112 | hithadhoo
# Processing Record 113 | bredasdorp
# Processing Record 114 | victoria
# City not found. Skipping...
# Processing Record 115 | tasiilaq
# Processing Record 116 | yakeshi
# Processing Record 117 | durban
# Processing Record 118 | hamilton
# Processing Record 119 | quatre cocos
# City not found. Skipping...
# Processing Record 120 | bereda
# Processing Record 121 | tromso
# Processing Record 122 | severo-kurilsk
# Processing Record 123 | dukat
# Processing Record 124 | lufilufi
# Processing Record 125 | atuona
# Processing Record 126 | porangatu
# Processing Record 127 | rundu
# Processing Record 128 | nhulunbuy
# Processing Record 129 | marienburg
# Processing Record 130 | hay river
# Processing Record 131 | barrhead
# Processing Record 132 | mehamn
# Processing Record 133 | karratha
# Processing Record 134 | nuuk
# City not found. Skipping...
# Processing Record 135 | preobrazheniye
# Processing Record 136 | biak
# Processing Record 137 | katsuura
# City not found. Skipping...
# Processing Record 138 | oktyabrskoye
# Processing Record 139 | upernavik
# Processing Record 140 | kodiak
# Processing Record 141 | huanuco
# Processing Record 142 | kanker
# Processing Record 143 | oytal
# Processing Record 144 | san carlos del zulia
# Processing Record 145 | carrara
# Processing Record 146 | pemangkat
# Processing Record 147 | tokur
# Processing Record 148 | lindi
# Processing Record 149 | harindanga
# Processing Record 150 | grindavik
# Processing Record 151 | kruisfontein
# Processing Record 152 | berlevag
# Processing Record 153 | kindu
# Processing Record 154 | souris
# Processing Record 155 | los llanos de aridane
# Processing Record 156 | coihaique
# Processing Record 157 | samarai
# Processing Record 158 | seoul
# Processing Record 159 | vostok
# Processing Record 160 | lompoc
# Processing Record 161 | glenwood springs
# Processing Record 162 | waipawa
# Processing Record 163 | tukrah
# Processing Record 164 | smoljan
# Processing Record 165 | carnarvon
# Processing Record 166 | banda aceh
# Processing Record 167 | tonneins
# Processing Record 168 | teguise
# Processing Record 169 | saint-pierre-des-corps
# City not found. Skipping...
# Processing Record 170 | hobyo
# City not found. Skipping...
# Processing Record 171 | ilulissat
# Processing Record 172 | inuvik
# Processing Record 173 | luocheng
# Processing Record 174 | mecca
# Processing Record 175 | udimskiy
# Processing Record 176 | ukiah
# Processing Record 177 | safakulevo
# Processing Record 178 | shingu
# Processing Record 179 | olga
# Processing Record 180 | port-gentil
# Processing Record 181 | sakakah
# Processing Record 182 | sechura
# Processing Record 183 | obo
# Processing Record 184 | chernushka
# Processing Record 185 | dikson
# Processing Record 186 | san patricio
# Processing Record 187 | namatanai
# Processing Record 188 | nyurba
# Processing Record 189 | port keats
# Processing Record 190 | otukpo
# Processing Record 191 | gumdag
# City not found. Skipping...
# Processing Record 192 | seymchan
# Processing Record 193 | east london
# Processing Record 194 | arlit
# Processing Record 195 | kiunga
# Processing Record 196 | mahibadhoo
# Processing Record 197 | pevek
# Processing Record 198 | lavrentiya
# Processing Record 199 | sao jose da coroa grande
# Processing Record 200 | saint-louis
# Processing Record 201 | maromitsa
# Processing Record 202 | aden
# Processing Record 203 | arraial do cabo
# Processing Record 204 | port shepstone
# Processing Record 205 | mount gambier
# Processing Record 206 | westport
# Processing Record 207 | odweyne
# Processing Record 208 | taksimo
# Processing Record 209 | le port
# Processing Record 210 | mukhen
# Processing Record 211 | loreto
# Processing Record 212 | lagoa
# Processing Record 213 | makakilo city
# City not found. Skipping...
# Processing Record 214 | lata
# Processing Record 215 | nikolskoye
# Processing Record 216 | andrelandia
# Processing Record 217 | inta
# Processing Record 218 | griffith
# Processing Record 219 | san jeronimo
# Processing Record 220 | mar del plata
# Processing Record 221 | natal
# Processing Record 222 | dawlatabad
# Processing Record 223 | cabo san lucas
# Processing Record 224 | igarka
# Processing Record 225 | bluff
# Processing Record 226 | abbeville
# Processing Record 227 | namibe
# Processing Record 228 | axim
# Processing Record 229 | waingapu
# Processing Record 230 | tual
# Processing Record 231 | merrill
# Processing Record 232 | torbay
# Processing Record 233 | longyearbyen
# Processing Record 234 | huarmey
# Processing Record 235 | derzhavinsk
# Processing Record 236 | galway
# Processing Record 237 | juegang
# Processing Record 238 | cayenne
# Processing Record 239 | tuatapere
# Processing Record 240 | cidreira
# Processing Record 241 | narsaq
# Processing Record 242 | yelizovo
# Processing Record 243 | broome
# Processing Record 244 | neiafu
# Processing Record 245 | dzerzhinskoye
# Processing Record 246 | khani
# Processing Record 247 | port lincoln
# Processing Record 248 | ternate
# Processing Record 249 | lyskovo
# Processing Record 250 | souillac
# Processing Record 251 | black river
# Processing Record 252 | qasigiannguit
# City not found. Skipping...
# Processing Record 253 | bayonet point
# Processing Record 254 | mugur-aksy
# Processing Record 255 | sorland
# Processing Record 256 | baherden
# Processing Record 257 | isangel
# Processing Record 258 | sur
# Processing Record 259 | lichinga
# Processing Record 260 | whitehorse
# Processing Record 261 | havelock
# Processing Record 262 | tambilil
# Processing Record 263 | ibra
# Processing Record 264 | codrington
# Processing Record 265 | asbe teferi
# Processing Record 266 | amahai
# Processing Record 267 | margate
# Processing Record 268 | neuquen
# Processing Record 269 | general roca
# Processing Record 270 | marshall
# City not found. Skipping...
# Processing Record 271 | lucapa
# Processing Record 272 | nanortalik
# Processing Record 273 | hasaki
# Processing Record 274 | buenos aires
# Processing Record 275 | praia da vitoria
# Processing Record 276 | vardo
# Processing Record 277 | curanilahue
# City not found. Skipping...
# Processing Record 278 | pudozh
# Processing Record 279 | bichena
# Processing Record 280 | klaksvik
# Processing Record 281 | zhangye
# Processing Record 282 | xiangfan
# Processing Record 283 | lannion
# Processing Record 284 | krasnoarmeysk
# Processing Record 285 | pietersburg
# Processing Record 286 | sinnamary
# Processing Record 287 | seryshevo
# Processing Record 288 | antalaha
# Processing Record 289 | kholm
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 290 | pangnirtung
# Processing Record 291 | yerbogachen
# Processing Record 292 | ritchie
# Processing Record 293 | tibati
# Processing Record 294 | sangar
# Processing Record 295 | maceio
# Processing Record 296 | nouadhibou
# Processing Record 297 | phuket
# Processing Record 298 | caslav
# Processing Record 299 | provideniya
# Processing Record 300 | bemidji
# Processing Record 301 | malokakhovka
# City not found. Skipping...
# Processing Record 302 | dukhovnitskoye
# Processing Record 303 | majene
# Processing Record 304 | college
# Processing Record 305 | palmer
# Processing Record 306 | mountain home
# Processing Record 307 | daru
# City not found. Skipping...
# Processing Record 308 | sarahan
# Processing Record 309 | nadym
# Processing Record 310 | imeni poliny osipenko
# Processing Record 311 | kieta
# City not found. Skipping...
# Processing Record 312 | abu dhabi
# Processing Record 313 | bengkulu
# Processing Record 314 | lyantonde
# Processing Record 315 | hofn
# Processing Record 316 | sherbakul
# Processing Record 317 | billings
# Processing Record 318 | orsha
# Processing Record 319 | aykhal
# Processing Record 320 | mahuva
# Processing Record 321 | hojai
# Processing Record 322 | aksu
# Processing Record 323 | kanuma
# Processing Record 324 | ponta delgada
# Processing Record 325 | mount isa
# Processing Record 326 | itapirapua
# Processing Record 327 | dingle
# Processing Record 328 | cartagena del chaira
# Processing Record 329 | cockburn town
# Processing Record 330 | laguna
# Processing Record 331 | aleksandrovskiy zavod
# Processing Record 332 | stromness
# Processing Record 333 | kemlya
# Processing Record 334 | qui nhon
# Processing Record 335 | gidam
# Processing Record 336 | alofi
# Processing Record 337 | jawhar
# City not found. Skipping...
# Processing Record 338 | pangkalanbuun
# Processing Record 339 | mitsamiouli
# Processing Record 340 | qinzhou
# Processing Record 341 | alice springs
# Processing Record 342 | constitucion
# Processing Record 343 | srandakan
# Processing Record 344 | kuusamo
# Processing Record 345 | saint-francois
# Processing Record 346 | ariquemes
# Processing Record 347 | marawi
# Processing Record 348 | norman wells
# Processing Record 349 | garowe
# Processing Record 350 | patacamaya
# Processing Record 351 | kloulklubed
# Processing Record 352 | phan thiet
# Processing Record 353 | vyartsilya
# Processing Record 354 | rio grande
# Processing Record 355 | sitka
# City not found. Skipping...
# Processing Record 356 | matara
# Processing Record 357 | caravelas
# Processing Record 358 | bijie
# Processing Record 359 | rio gallegos
# Processing Record 360 | truckee
# Processing Record 361 | malanje
# Processing Record 362 | vila velha
# Processing Record 363 | den helder
# Processing Record 364 | sao luiz gonzaga
# Processing Record 365 | pijijiapan
# Processing Record 366 | faanui
# Processing Record 367 | cabras
# Processing Record 368 | scarborough
# Processing Record 369 | vila franca do campo
# Processing Record 370 | coquimbo
# Processing Record 371 | guerrero negro
# City not found. Skipping...
# Processing Record 372 | pajan
# City not found. Skipping...
# Processing Record 373 | te anau
# Processing Record 374 | aasiaat
# Processing Record 375 | ulladulla
# Processing Record 376 | batagay
# Processing Record 377 | eureka
# Processing Record 378 | trud
# Processing Record 379 | simao
# Processing Record 380 | katherine
# Processing Record 381 | orlik
# Processing Record 382 | pisco
# Processing Record 383 | buritizeiro
# Processing Record 384 | imbituba
# Processing Record 385 | livingstonia
# Processing Record 386 | athens
# Processing Record 387 | awjilah
# Processing Record 388 | wilmington
# Processing Record 389 | mandalgovi
# Processing Record 390 | pedernales
# Processing Record 391 | honningsvag
# Processing Record 392 | rumuruti
# City not found. Skipping...
# Processing Record 393 | jermuk
# Processing Record 394 | kutum
# Processing Record 395 | rovaniemi
# Processing Record 396 | barmer
# Processing Record 397 | moose factory
# Processing Record 398 | tanout
# City not found. Skipping...
# Processing Record 399 | bambanglipuro
# Processing Record 400 | kurchum
# Processing Record 401 | ciudad bolivar
# Processing Record 402 | santa rosa
# Processing Record 403 | luau
# Processing Record 404 | tommot
# Processing Record 405 | cranbrook
# Processing Record 406 | parkersburg
# Processing Record 407 | nizhniy tsasuchey
# Processing Record 408 | asau
# Processing Record 409 | saint-pierre
# Processing Record 410 | libertador general san martin
# Processing Record 411 | havoysund
# Processing Record 412 | petropavl
# Processing Record 413 | boke
# Processing Record 414 | myitkyina
# Processing Record 415 | bandarbeyla
# Processing Record 416 | maniitsoq
# Processing Record 417 | zhaotong
# Processing Record 418 | huilong
# Processing Record 419 | caraquet
# Processing Record 420 | lixourion
# Processing Record 421 | paris
# Processing Record 422 | martapura
# Processing Record 423 | zunyi
# Processing Record 424 | gushikawa
# Processing Record 425 | channel-port aux basques
# Processing Record 426 | vao
# Processing Record 427 | portland
# City not found. Skipping...
# Processing Record 428 | miami lakes
# Processing Record 429 | kulhudhuffushi
# City not found. Skipping...
# Processing Record 430 | xuddur
# Processing Record 431 | awbari
# Processing Record 432 | haines junction
# Processing Record 433 | ugoofaaru
# Processing Record 434 | catuday
# Processing Record 435 | novyy urengoy
# Processing Record 436 | two hills
# Processing Record 437 | puerto cabezas
# Processing Record 438 | maloy
# Processing Record 439 | burns lake
# Processing Record 440 | avera
# Processing Record 441 | auki
# Processing Record 442 | kavaratti
# Processing Record 443 | alyangula
# Processing Record 444 | talnakh
# Processing Record 445 | umm kaddadah
# Processing Record 446 | ubinskoye
# City not found. Skipping...
# Processing Record 447 | tiznit
# Processing Record 448 | fairbanks
# Processing Record 449 | muisne
# Processing Record 450 | sayyan
# Processing Record 451 | zabaykalsk
# Processing Record 452 | najran
# Processing Record 453 | hualmay
# Processing Record 454 | esperance
# Processing Record 455 | sao miguel do araguaia
# Processing Record 456 | santa cruz
# Processing Record 457 | tallahassee

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
#
#
#
#
# * Display the DataFrame

# %%
city_df = pd.DataFrame({
    'City': city_list,
    'Cloudiness': cloudiness,
    'Country': country,
    'Date': date,
    'Humidity': humidity,
    'Lat': lat,
    'Lng': lng,
    'Max Temp': max_temp,
    'Wind Speed': wind_speed
})

display(city_df)

# Export Dataframe into a .csv
# city_df.to_csv(output_data_file)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_df.loc[city_df['Humidity']>100]

# %%
city_df.loc[city_df['Cloudiness']<=100]

# %%
#  Get the indices of cities that have humidity over 100%.
indicies_to_drop=city_df.loc[city_df['Humidity']>100].index

cleancitydata=city_df.drop(indicies_to_drop)

# %%
cleancitydata

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

new_city_df = pd.DataFrame({
    'City': city_list,
    'Cloudiness': cloudiness,
    'Country': country,
    'Date': date,
    'Humidity': humidity,
    'Lat': lat,
    'Lng': lng,
    'Max Temp': max_temp,
    'Wind Speed': wind_speed
})

display(new_city_df)

# %%
# plt.show("")

# %%
# x_values ['latitude']
# y_values ['max temps']
# plt.scatter(x_values,y_values)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Max Temp'

x = city_df['Lat']
y = city_df['Max Temp']

# Set color to the value of 'Max Temp' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='Greens', edgecolor='gray')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Max Temperature ({date})')
plt.grid()

# Save plot as png file in output folder
plt.savefig('../output_data/Lat_v_Temp.png')

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Humidity'

x = city_df['Lat']
y = city_df['Humidity']

# Set color to the value of 'Humidity' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='PuBuGn', edgecolor='gray')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Humidity ({date})')
plt.grid()

# Save plot as png file in output folder
plt.savefig('../output_data/Lat_v_Humidity.png')

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Cloudiness'

x = city_df['Lat']
y = city_df['Cloudiness']

# Set color to the value of 'Cloudiness' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='GnBu', edgecolor='gray')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Cloudiness ({date})')
plt.grid()

# Save plot as png file in output folder
plt.savefig('../output_data/Lat_v_Cloudiness.png')

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Wind Speed'

x = city_df['Lat']
y = city_df['Wind Speed']

# Set color to the value of 'Wind Speed' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='YlGn', edgecolor='gray')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs. Wind Speed ({date})')
plt.grid()

# Save plot as png file in output folder
plt.savefig('../output_data/Lat_v_WindSpeed.png')

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
def regressplot(x, y):
    
    correlation = st.pearsonr(x,y)

    # Print the answer to above calculation, but squared
    print(f"""The r-squared value is {round((correlation[0]**2),2)}""")

    # Calculate linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Plot linear regression on top of scatter plot
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# %%
northern_hemi=city_df.loc[city_df['Lat'] >=0]
southern_hemi=city_df.loc[city_df['Lat'] < 0]
southern_hemi

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#  north and south dataframes
line_eq = regressplot(x = northern_hemi['Lat'], y = northern_hemi['Max Temp'])

# Annotate linear regression
plt.annotate(line_eq,(10,-10),fontsize=15,color="green")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

plt.savefig('../output_data/North_Temp.png')

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = southern_hemi['Lat'], y = southern_hemi['Max Temp'])

# Annotate linear regression
plt.annotate(line_eq,(-30,52),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

plt.savefig('../output_data/South_Temp.png')

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = northern_hemi['Lat'], y = northern_hemi['Humidity'])

# Annotate linear regression
plt.annotate(line_eq,(45,10),fontsize=15,color="blue")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig('../output_data/North_Humidity.png')

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = southern_hemi['Lat'], y = southern_hemi['Humidity'])

# Annotate linear regression
plt.annotate(line_eq,(-25,40),fontsize=15,color="green")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig('../output_data/South_Humidity.png')

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = northern_hemi['Lat'], y = northern_hemi['Cloudiness'])

# Annotate linear regression
plt.annotate(line_eq,(45,60),fontsize=15,color="green")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig('../output_data/North_Cloudiness.png')

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
city

# The correlation between these values in both hemispheres is almost identical.

# %%
# Regression Function and pass appropriate parameters
line_eq = regressplot(x = southern_hemi['Lat'], y = southern_hemi['Cloudiness'])

# Annotate linear regression
plt.annotate(line_eq,(-57,50
                     ),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig('../output_data/South_Cloudiness.png')

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Regression Function and pass appropriate parameters
line_eq = regressplot(x = northern_hemi['Lat'], y = northern_hemi['Wind Speed'])

# Annotate linear regression
plt.annotate(line_eq,(10,30),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig('../output_data/North_WindSpeed.png')

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = southern_hemi['Lat'], y = southern_hemi['Wind Speed'])

# Annotate linear regression
plt.annotate(line_eq,(-48,22),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig('../output_data/South_WindSpeed.png')

plt.show()

# %%
# fnjnvjksnvjfdnioreisfnionnsldnvk
